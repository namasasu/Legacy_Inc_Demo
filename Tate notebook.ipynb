-- %%
-- Create catalog and set as active
CREATE CATALOG IF NOT EXISTS LEGACY_INC;
USE CATALOG LEGACY_INC;

-- Create schemas for bronze, silver, and gold layers
CREATE SCHEMA IF NOT EXISTS bronze comment 'bronze schema';
CREATE SCHEMA IF NOT EXISTS silver comment 'silver schema';
CREATE SCHEMA IF NOT EXISTS gold comment 'gold schema';

-- Create volume for landing zone in bronze schema
CREATE VOLUME bronze.landing COMMENT 'landing zone';
--CREATE VOLUME bronze.staging COMMENT 'staging zone';
--CREATE VOLUME bronze.processed COMMENT 'processed zone';

-- Grant all privileges on catalog to specified user
GRANT ALL PRIVILEGES ON CATALOG LEGACY_INC TO `tatendanamasasu99@gmail.com`;

--GRANT USE SCHEMA ON SCHEMA bronze TO `account users`;
--GRANT USE SCHEMA ON SCHEMA silver TO `account users`;
